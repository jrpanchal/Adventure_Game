# %%
"""
DocString:
    
    Welcome to Hogwarts, you are going to help Harry save the day. This is a 
    Harry Potter Minature Adventure Game. 

    Answer the following questions: Player must answer the following questions 
    correctly to uncover the missing student's name and entrance to the tunnel and use the 
    correct spell in order to win the day. 
    
    ****Bugs: No known errors
       
    
"""

#importing random for scene 3
import random
import sys
from sys import exit
from random import randint


#starts the game
def intro_1(): 
    global user_name #going to use this input at the end if user wins
    
#introduction to the game for the user
    print(f""" Welcome to Hogwarts, where new magic can be discovered. You are 
    going to help Harry save the day. This is a Harry Potter Minature Adventure Game. 
    
    Answer the following questions: player must beat their opponent and use the 
    correct spell in order to win the day. 
""")     
    
       
#user name input 
    user_name = input (prompt = "What is your name young wizard?:\n")
    print(f"Are you ready to play {user_name.capitalize()}? yes/no")

    answer = input (prompt = '') 
    answer = answer.lower()
#condition statment to start the game
    if answer == "yes" or answer == "y":
        print("Great choice!")
        
    else:
        print(f"""Aw. Sad. Who doesn't love Hogwarts! Well check it out 
        anyways, maybe you will.
""") 
#either way the game will start--- giving a pause to continue with the scene
    input('<Press enter to continue>\n')   
    scene_1()  
    
#########################################################
# Adding scene_1 and linking it to intro_1 
#########################################################        
        
#setting the scene
def scene_1():
    print(f"""Scene: It was a cold winter night at Hogwarts. Everyone was 
    sleeping in their chamber besides the headmasters and professors. They were 
    at the round table discussing missing students and the bookeeper barges 
    in 'the air of slytherin has left another message.' 
""")
    print(f"""'Her skelton will lie in the chamber forever.'""")
    
#User guess the dead student
    dead_guess  = input(prompt="A student has been snatched by the monster. Who do you think it is?:\n")
    

    print(f""" 
    
    You think it is {dead_guess.capitalize()}? Well, Harry and Ron use Harry's  
    invisible cloak and listens in. Quickly rushes to the scene and see a dead 
    bloody cat.
    
""")
#Moves to the next scene
    scene_2() 
    
    input('<Press enter to continue>\n')
    
    
#########################################################
# Adding scene_1 and linking it to scene_2
######################################################### 

#leading into the 2nd scene
def scene_2(): 

    print(f"""
            After they see the dead bloody cat.
            1. Investigate on their own and open the bathroom stall
            2. Call for help?"
            3. Petrified, decide to never speak of this moment again!
""")
          
    next_steps= input(prompt = "What do they do next?”:\n")
    
    if '1' in next_steps or 'investigate' in next_steps: 
        scene_3() 

    elif '2' in next_steps or 'call for help' in next_steps or 'help'in next_steps:
        print(f"""That's incorrect. Harry and Ron just got caught for breaking 
              the Hogwart's rule. The teacher deducts 10 points and returns them to their chamber.""")
        fail() #Harry never calls for help he believes in doing everything alone
    
    elif '3' in next_steps or 'petrified'in next_steps:  
        print("You sent Harry and Ron back home to become muggles again.")
        fail()
        
    else: 
        print("Invalid entry. Please try again:\n")
        scene_2()
        
    input('<Press enter to continue>\n')
#########################################################
# Adding scene_2 and linking it to scene_3 
######################################################### 
        

#last scene for the game
def scene_3():

    print(f""" That's right. As they open the door they see a ghost, it's Moaning Myrtle! 
(with her creepy laugh...hehehehhe) I will tell you who was taken and how to get to entrance of 
the chamber of secrets only if you answer these questions. She's a little sensitive, 
so make sure you answer the questions carefully.  
""")

#creating the list of questions the ghost asks Harry with condition statements
    question_lst = ['What are you doing here?',
                    'Guess my favorite number from 1-5?',
                    'What’s the protection spell?']
    
#already imported random, random sample should choose 2 questions from the list for input. 
 # while loop
    while question_lst:
        question = random.choice(question_lst)
        
        #remove the question 
        question_lst.remove(question)
        
        input('<Press enter to continue>\n')
        print(question)
    
#for random in         
############ 1st question is chosen from the question_lst
        if 'What are you doing here?' in question: 
        
#user input and fairly easy 
            action= input(prompt='') 
            print(f"Oh okay, fine you can {action}.")
        
############# 2nd question is chosen from the question_lst       
#generating a random number
        if 'Guess my favorite number from 1-5?' in question:
        #elif question == question_lst [1]: 
        
            number= random.randint(a=1,
                                   b=5)
    #user guessing a number
            print("I'm going to be so sad and cry all night, if you get it wrong.")
            guess = input(prompt= f"""Pick a number between 1 and 5. 
            Can I give you a hint? Please? It's {number}.:\n
""")
    #guess into integer
            guess = int(guess)

            if guess == number: 
                    print("Good job!")
            else: 
                print(f"Nice try, but I was thinking of the number {number}.")
                fail()
                
################# 3rd question is chosen from the question _lst
        if 'What’s the protection spell?' in question:
        #elif question == question_lst [2] 

            print(f"""
                    1. Reparo 
                    2. Protego
                    3. Expecto Patronum
""")
            spell= input(prompt="I need to make sure you are going to be safe. (Please input 1,2,or 3.):\n")

            if spell=='1':
                print("Yikes, I'm sorry. This is the end of your journey.")
                fail()

            elif spell =='2':
                print("You're skills are legendary!")
                
            elif spell=='3':
                print("I know that's Harry's favorite spell, but that's incorrect.")
                fail()
            else: 
                print("Invalid entry.")

    winner()
    
#########################################################
# Adding scene_3 and linking it to winner()
######################################################### 
def winner():
    print(f""" Awesome! I'm afraid the monster's have taken Ginney Weasley 
    and the entrance to the chamber is through the bathroom tunnel. Congratulations 
    {user_name.capitalize()}: You've successfully help Harry solve the case.""")
    print("Wait for level 2 to come out.")
    input('<Press any key to continue>\n')
    exit(0)
    
#########################################################
# Adding winner() and linking it to fail()
######################################################### 

def fail(): 
    print(f""" {user_name.capitalize()}: You're journey ends here, looks like you couldn't
    help Harry afterall. 
""")

    print(f""" Would you like to try again? {user_name.capitalize()} Please type yes or no.""")
    replay = input(">")
    replay = replay.lower()
    
    if replay == 'yes':
        intro_1() 
   
    elif replay =='no':
        print("""Thanks for playing! I'll leave you 
              with this, on a scale of 1 to 10, how obsessed with the Harry 
              Potter Series am I?""")
        exit(0)
    else: 
        print("Please input the correct response.")
        fail()

intro_1()
# Out:
#  Welcome to Hogwarts, where new magic can be discovered. You are
#     going to help Harry save the day. This is a Harry Potter Minature Adventure Game.
#
#     Answer the following questions: player must beat their opponent and use the
#     correct spell in order to win the day.
